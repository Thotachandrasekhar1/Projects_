# %% [markdown]
# # ***Brain Tumor Prediction Using Naive Bayes***

# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Loading the dataset

# %%
df = pd.read_csv(r"C:\Users\THOTA CHANDRASEKHAR\Downloads\Machine Learning\Projects\Brain-tumor-detection.csv",usecols=[1,2,3,4,5,6,7,8,9]) #usecol parameter will select only which useful to analysis

# %%
df.head()
# Out:
#       Area    Perimeter  Convex Area  Solidity  Equivalent Diameter  \
# 0   6314.5   521.972649       9855.5  0.640708            89.665328
# 1  52776.5  1189.820409      59947.0  0.880386           259.224086
# 2  50232.5  1415.349410      69628.5  0.721436           252.899200
# 3   4486.0   275.622365       4741.5  0.946114            75.576138
# 4    145.0    92.083260        323.5  0.448223            13.587484
#
#    Major Axis  Minor Axis                                 Eccentricity  Class
# 0   86.297539  146.952896  (8.439724311699382e-17+1.3783115780934465j)      1
# 1  209.590240  405.861420  (1.015395044877726e-16+1.6582659515946696j)      1
# 2  223.632736  373.077637  (8.176507178841775e-17+1.3353249581078526j)      1
# 3   64.818382   93.083397  (6.311037889163952e-17+1.0306707033502136j)      1
# 4   16.900970   28.915043   (8.50007943665633e-17+1.3881683180120858j)      1

# %% [markdown]
# ## Exploratory Data Analysis

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 241 entries, 0 to 240
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Area                 241 non-null    float64
#  1   Perimeter            241 non-null    float64
#  2   Convex Area          241 non-null    float64
#  3   Solidity             241 non-null    float64
#  4   Equivalent Diameter  241 non-null    float64
#  5   Major Axis           241 non-null    float64
#  6   Minor Axis           241 non-null    float64
#  7   Eccentricity         241 non-null    object
#  8   Class                241 non-null    int64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 17.1+ KB

# %%
#missing values detection
df.isna().sum()
# Out:
# Area                   0
# Perimeter              0
# Convex Area            0
# Solidity               0
# Equivalent Diameter    0
# Major Axis             0
# Minor Axis             0
# Eccentricity           0
# Class                  0
# dtype: int64

# %%
#duplicate values detection 
df.duplicated().sum()
# Out:
# 51

# %%
df.drop_duplicates(inplace=True)

# %%
#Typecasting 

df['Eccentricity'] = df['Eccentricity'].astype('complex')
df.Class = df.Class.astype('object')
print(df.dtypes)
# Out:
# Area                      float64
# Perimeter                 float64
# Convex Area               float64
# Solidity                  float64
# Equivalent Diameter       float64
# Major Axis                float64
# Minor Axis                float64
# Eccentricity           complex128
# Class                      object
# dtype: object

# %%
#structural errors
df.columns = df.columns.str.lower()
df.columns = df.columns.str.replace(' ','_')

# %%
df['eccentricity'] = df['eccentricity'].apply(lambda x: abs(x))

# %%
df['eccentricity'] = df['eccentricity'].astype('float')

# %%
#outliers
for i in df.select_dtypes(exclude=['object']).columns:
    df[i].plot.box()
    plt.show()

# %% [markdown]
# Area:
#
#     Small tumor: 50 square millimeters
#     Large tumor: 5000 square millimeters
#
# Perimeter:
#
#     Irregularly shaped tumor: 30 millimeters
#     Circular tumor: 100 millimeters
# Convex Area:
#
#     Small, irregular tumor: 40 square millimeters
#     Large, more convex tumor: 3000 square millimeters
# Solidity:
#
#     Compact, solid tumor: 0.9
#     More irregular, less solid tumor: 0.6
# Equivalent Diameter:
#
#     Small tumor: 10 millimeters
#     Large tumor: 80 millimeters
# Major Axis and Minor Axis:
#
#     Elongated tumor: Major Axis - 40 millimeters, Minor Axis - 20 millimeters
#     Circular tumor: Major Axis - 30 millimeters, Minor Axis - 30 millimeters

# %%
#outliers
for i in df.select_dtypes(exclude=['object']).columns:
    print(i)
    df[i].plot.kde()
    plt.show()
# Out:
# area
# perimeter
# convex_area
# solidity
# equivalent_diameter
# major_axis
# minor_axis
# eccentricity

# %%
df['class'] = df['class'].map({1 :"Tumor detected", 0: "No tumor detected"})

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# ### Feature Selection

# %%
df = df.drop(['major_axis','minor_axis'],axis=1) #these columns columns are not useful to analysis because combination these two columns is eccentricity

# %%
df
# Out:
#         area    perimeter  convex_area  solidity  equivalent_diameter  \
# 0     6314.5   521.972649       9855.5  0.640708            89.665328
# 1    52776.5  1189.820409      59947.0  0.880386           259.224086
# 2    50232.5  1415.349410      69628.5  0.721436           252.899200
# 3     4486.0   275.622365       4741.5  0.946114            75.576138
# 4      145.0    92.083260        323.5  0.448223            13.587484
# ..       ...          ...          ...       ...                  ...
# 236    545.5   208.267025       1317.5  0.414042            26.354358
# 237    902.0   232.166520       1444.5  0.624438            33.888967
# 238   3177.0   217.681239       3260.0  0.974540            63.600959
# 239   6103.0  1208.631593      51259.5  0.119061            88.150899
# 240    250.0    66.769552        264.0  0.946970            17.841241
#
#      eccentricity              class
# 0        1.378312     Tumor detected
# 1        1.658266     Tumor detected
# 2        1.335325     Tumor detected
# 3        1.030671     Tumor detected
# 4        1.388168     Tumor detected
# ..            ...                ...
# 236      2.013375  No tumor detected
# 237      1.800646  No tumor detected
# 238      0.296509  No tumor detected
# 239      0.206967  No tumor detected
# 240      1.772417  No tumor detected
#
# [190 rows x 7 columns]

# %%
sns.heatmap(df.corr(numeric_only=True),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ### Splitting the data into input and output features

# %%
X = df.drop('class',axis=1)
y = df['class']

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import RobustScaler ,MinMaxScaler, PowerTransformer,StandardScaler,MaxAbsScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.naive_bayes import GaussianNB

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25,random_state=42)

# %%
num_col = X_train.select_dtypes(exclude='object').columns

# %%
num_trans = Pipeline(steps=[('Scaler',RobustScaler()),
               ("transformation",PowerTransformer())])

# %%
preprocess = ColumnTransformer([('Step 1',num_trans,num_col)
                  ])

# %%
pipe = Pipeline([('Preprocess',preprocess),
         ('Model',GaussianNB())])

# %%
pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('Preprocess',
#                  ColumnTransformer(transformers=[('Step 1',
#                                                   Pipeline(steps=[('Scaler',
#                                                                    RobustScaler()),
#                                                                   ('transformation',
#                                                                    PowerTransformer())]),
#                                                   Index(['area', 'perimeter', 'convex_area', 'solidity', 'equivalent_diameter',
#        'eccentricity'],
#       dtype='object'))])),
#                 ('Model', GaussianNB())])

# %%
y_pred = pipe.predict(X_test)

# %%
n = np.array([7465.0,1921.214415,130247.0,0.057314,97.492221,0.594490])
numeric_features = ['area', 'perimeter', 'convex_area', 'solidity', 'equivalent_diameter', 'eccentricity']
n_df = pd.DataFrame([n], columns=numeric_features)

pipe.predict(n_df)
# Out:
# array(['Tumor detected'], dtype='<U17')

# %%
X_test
# Out:
# 15       1.261558
# 9        1.142527
# 16       0.949815
# 170      2.008338
# 145      1.433137
# 125      0.696759
# 107      1.115862
# 18       0.859521
# 209      1.688107
# 95       0.773728
# 140      0.847685
# 118      1.765419
# 72       0.471099
# 60       1.542633
# 45       0.848077
# 30       0.918634
# 24       1.042869
# 197      0.250443
# 109      0.749280
# 74       1.006022
# 148      2.592807
# 144      0.836956
# 19       0.834619
# 49       0.727317
# 81       1.458592
# 215      0.782747
# 73       1.384402
# 5        1.186071
# 158      2.347312
# 217      1.368124
# 207      1.343625
# 85       0.840872
# 130      0.808846
# 55       1.306842
# 36       2.686769
# 138      0.729937
# 65       1.942288
# 204      1.106041
# 83       1.922581
# 75       1.099322
# 29       0.839886
# 149      0.000000
# 191      0.759180

# %%
X_train
# Out:
#         area   perimeter  convex_area  solidity  equivalent_diameter  \
# 211     61.5   31.899495         65.5  0.938931             8.848968
# 31   10355.0  473.587874      11766.0  0.880078           114.823323
# 195  57177.0  912.607209      57611.0  0.992467           269.814784
# 12     395.0   76.083260        408.5  0.966952            22.426092
# 44     646.0  218.994947       1071.5  0.602893            28.679483
# ..       ...         ...          ...       ...                  ...
# 121   6127.0  365.161468       6983.0  0.877417            88.324055
# 14    1160.5  203.580734       1674.0  0.693250            38.439491
# 103    331.0  135.195958        798.5  0.414527            20.529060
# 228    565.5  190.953318       1225.5  0.461444            26.833132
# 116   4464.0  448.073155       6076.0  0.734694            75.390592
#
#      eccentricity
# 211      0.860512
# 31       0.938122
# 195      0.880179
# 12       0.415616
# 44       0.334688
# ..            ...
# 121      0.744808
# 14       2.387821
# 103      1.513443
# 228      0.632852
# 116      1.394921
#
# [142 rows x 6 columns]

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report,ConfusionMatrixDisplay,f1_score,recall_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.7291666666666666

# %%
f1_score(y_test,y_pred,pos_label='No tumor detected')
# Out:
# 0.5517241379310345

# %%
recall_score(y_test,y_pred,pos_label='No tumor detected')
# Out:
# 0.6666666666666666

# %%
print(classification_report(y_test,y_pred))
# Out:
#                    precision    recall  f1-score   support
#
# No tumor detected       0.47      0.67      0.55        12
#    Tumor detected       0.87      0.75      0.81        36
#
#          accuracy                           0.73        48
#         macro avg       0.67      0.71      0.68        48
#      weighted avg       0.77      0.73      0.74        48

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[ 8,  4],
#        [ 9, 27]], dtype=int64)

# %%
    ConfusionMatrixDisplay(confusion_matrix(y_test,y_pred)).plot()

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = Pipeline([('Preprocess',preprocess),
         ('Model',KNeighborsClassifier())])

# %%
knn.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('Preprocess',
#                  ColumnTransformer(transformers=[('Step 1',
#                                                   Pipeline(steps=[('Scaler',
#                                                                    RobustScaler()),
#                                                                   ('transformation',
#                                                                    PowerTransformer())]),
#                                                   Index(['area', 'perimeter', 'convex_area', 'solidity', 'equivalent_diameter',
#        'eccentricity'],
#       dtype='object'))])),
#                 ('Model', KNeighborsClassifier())])

# %%
y_pred = knn.predict(X_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.7708333333333334

# %%
    ConfusionMatrixDisplay(confusion_matrix(y_test,y_pred)).plot()

# %%
import pickle
with open('gaussian_brain.pkl', 'wb') as model_file:
    pickle.dump(pipe, model_file)
